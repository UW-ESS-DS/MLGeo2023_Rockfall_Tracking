# %%
import gdown
 
#url = 'https://drive.google.com/uc?id=1hcxS1oOlMORTKsXluXZj2Zv9qTGJVenj' # Note how this link is slightly modified from the Google Drive copied link
url = 'https://drive.google.com/uc?id=1V2rOk9NJOz_5zgcIkedtQIhqJJQx35kN'
output = 'download.tiff'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1V2rOk9NJOz_5zgcIkedtQIhqJJQx35kN
# To: /home/jovyan/download.tiff
# 100%|██████████| 33.2M/33.2M [00:00<00:00, 58.5MB/s]
# 'download.tiff'
